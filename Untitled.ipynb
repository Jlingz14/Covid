# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.basemap import Basemap
from itertools import chain

# %%
data = pd.read_csv("covid_19_clean_complete.csv")
data.head()
# Out:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22          0
# 2            NaN        Algeria  28.03390   1.659600  2020-01-22          0
# 3            NaN        Andorra  42.50630   1.521800  2020-01-22          0
# 4            NaN         Angola -11.20270  17.873900  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe
# 2       0          0       0                 Africa
# 3       0          0       0                 Europe
# 4       0          0       0                 Africa

# %%
lat = data['Lat'].values
lon = data['Long'].values
Confirmé = data['Confirmed'].diff().values
Mort = data['Deaths'].diff().values

# %%
def draw_map(m, scale=0.2):
    m.shadedrelief(scale=scale)
    lats = m.drawparallels(np.linspace(-90, 90, 15))
    lons = m.drawmeridians(np.linspace(-180, 180, 15))
    
    lat_lines = chain(*(tup[1][0] for tup in lats.items()))
    lon_lines = chain(*(tup[1][0] for tup in lons.items()))
    all_lines = chain(lat_lines, lon_lines)
    
    for line in all_lines:
        line.set(linestyle='-', alpha=0.9, color='w')
        
fig = plt.figure(figsize=(30,10), edgecolor='w')
m = Basemap(projection='cyl', resolution=None,llcrnrlat=-90, urcrnrlat=90,llcrnrlon=-180, urcrnrlon=180, )
draw_map(m)

m.scatter(lon, lat, latlon=True,c=Mort, s=Confirmé/250, alpha=0.1,cmap='viridis')
plt.colorbar(label='Mortalité')
plt.clim(100, 100000)

for a in [1000, 5000, 10000]:
    plt.scatter([], [], c='k', alpha=0.4, s=a,label=str(a))

       
plt.legend(scatterpoints=1, frameon=False,labelspacing=8,loc='upper left');

# %%
df = pd.read_csv('Mada.csv')
df
# Out:
#        Country/Region        Lat       Long        Date  Nouveau_cas  \
# 0          Analamanga -18.382300  47.292300  2020-03-20            3
# 1          Analamanga -18.382300  47.292300  2020-03-21            0
# 2          Analamanga -18.382300  47.292300  2020-03-22            0
# 3          Analamanga -18.382300  47.292300  2020-03-23            9
# 4          Analamanga -18.382300  47.292300  2020-03-24            5
# ..                ...        ...        ...         ...          ...
# 379  Matsiatra-ambony -21.452670  47.085690  2020-07-24           11
# 380             Itasy -19.000000  46.766700  2020-07-24            5
# 381  Atsimo_Andrefana -23.350000  43.666670  2020-07-24            3
# 382        Atsinanana -14.455832  49.701497  2020-07-24            2
# 383             Sofia -15.200000  48.400000  2020-07-24            3
#
#      cas_Guerri  cas_mor  Confirmé  Guerrison  Mortalite
# 0             0        0         3          0          0
# ...

# %%
lat = df['Lat'].values
lon = df['Long'].values
Confirmé = df['Nouveau_cas'].values
Mort = df['cas_mor'].diff().values

# %%
def draw_map(m, scale=0.8):
    m.shadedrelief(scale=scale)
    lats = m.drawparallels(np.linspace(-90, 90, 15))
    lons = m.drawmeridians(np.linspace(-180, 180, 15))
    
    lat_lines = chain(*(tup[1][0] for tup in lats.items()))
    lon_lines = chain(*(tup[1][0] for tup in lons.items()))
    all_lines = chain(lat_lines, lon_lines)
    
    for line in all_lines:
        line.set(linestyle='-', alpha=0, color='w')
        
fig = plt.figure(figsize=(30,10), edgecolor='w')
m = Basemap(projection='cyl', resolution='c',llcrnrlat=-28, urcrnrlat=-10,llcrnrlon=42, urcrnrlon=52)
draw_map(m)

m.scatter(lon, lat, latlon=True,c=Mort, s=Confirmé*10, alpha=0.5,cmap='viridis')
plt.colorbar(label='Mortalité')
plt.clim(1, 5)

for a in [25,150,250,2000]:
    plt.scatter([], [], c='k', alpha=0.4, s=a,label=str(a))

       
plt.legend(scatterpoints=1, frameon=False,labelspacing=3,loc='upper left');
