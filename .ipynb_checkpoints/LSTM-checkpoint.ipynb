# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from pandas.tseries.offsets import DateOffset
import time
from statsmodels.tools.eval_measures import rmse
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout

# %%
data = pd.read_csv("full_grouped.csv")
data.rename(columns={'New cases':'New_cases'},inplace=True)
data.rename(columns={'New deaths':'New_deaths'},inplace=True)
data.rename(columns={'New recovered':'New_recovered'},inplace=True)

df = pd.DataFrame()
df['Date'] = data.loc[data['Country/Region']=='Madagascar'].Date
df['Confirmé'] = data.loc[data['Country/Region']=='Madagascar'].New_cases
df.Date = pd.to_datetime(df.Date)
df = df.set_index('Date')
df = df[58:]

# %%
df
# Out:
#             Confirmé
# Date
# 2020-03-20         3
# 2020-03-21         0
# 2020-03-22         0
# 2020-03-23         9
# 2020-03-24         5
# ...              ...
# 2020-06-30        76
# 2020-07-01        89
# 2020-07-02       100
# 2020-07-03       109
# 2020-07-04       216
#
# [107 rows x 1 columns]

# %%
train,test = df[12:],df[-12:]
scaler = MinMaxScaler()
scaler.fit(train)
train = scaler.transform(train)
test = scaler.transform(test)

# %%
train.shape
# Out:
# (95, 1)

# %%
n_input = 15
n_features = 1
generator = TimeseriesGenerator(train,train,length=n_input,batch_size=5)

model = Sequential()
model.add(LSTM(200,activation='relu',input_shape=(n_input,n_features)))
model.add(Dropout(0.1))
model.add(Dense(1))
model.compile(optimizer='adam',metrics='accuracy',loss='mse')

model.fit_generator(generator,epochs=50)
# Out:
# WARNING:tensorflow:From <ipython-input-6-d4dc58b32db1>:11: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/50
# 16/16 [==============================] - 1s 76ms/step - loss: 0.0233 - accuracy: 0.1625
# Epoch 2/50
# 16/16 [==============================] - 1s 59ms/step - loss: 0.0177 - accuracy: 0.1625
# Epoch 3/50
# 16/16 [==============================] - 1s 64ms/step - loss: 0.0141 - accuracy: 0.1625
# Epoch 4/50
# 16/16 [==============================] - 1s 74ms/step - loss: 0.0146 - accuracy: 0.1625
# Epoch 5/50
# 16/16 [==============================] - 1s 55ms/step - loss: 0.0109 - accuracy: 0.1750
# Epoch 6/50
# 16/16 [==============================] - 1s 66ms/step - loss: 0.0118 - accuracy: 0.1625
# Epoch 7/50
# 16/16 [==============================] - 1s 57ms/step - loss: 0.0108 - accuracy: 0.1750
# Epoch 8/50
# 16/16 [==============================] - 1s 67ms/step - loss: 0.0102 - accuracy: 0.1625
# Epoch 9/50
# 16/16 [==============================] - 1s 67ms/step - loss: 0.0092 - accuracy: 0.1750
# Epoch 10/50
# 16/16 [==============================] - 1s 71ms/step - loss: 0.0094 - accuracy: 0.1750
# Epoch 11/50
# 16/16 [==============================] - 1s 70ms/step - loss: 0.0097 - accuracy: 0.1750
# Epoch 12/50
# 16/16 [==============================] - 1s 65ms/step - loss: 0.0087 - accuracy: 0.1750
# Epoch 13/50
# 16/16 [==============================] - 1s 64ms/step - loss: 0.0086 - accuracy: 0.1750
# Epoch 14/50
# 16/16 [==============================] - 2s 101ms/step - loss: 0.0080 - accuracy: 0.1750
# Epoch 15/50
# 16/16 [==============================] - 1s 65ms/step - loss: 0.0088 - accuracy: 0.1750
# Epoch 16/50
# 16/16 [==============================] - 1s 62ms/step - loss: 0.0098 - accuracy: 0.1625
# Epoch 17/50
# 16/16 [==============================] - 1s 88ms/step - loss: 0.0108 - accuracy: 0.1750
# Epoch 18/50
# 16/16 [==============================] - 1s 81ms/step - loss: 0.0116 - accuracy: 0.1625
# Epoch 19/50
# 16/16 [==============================] - 1s 64ms/step - loss: 0.0097 - accuracy: 0.1625
# Epoch 20/50
# 16/16 [==============================] - 1s 74ms/step - loss: 0.0084 - accuracy: 0.1750
# Epoch 21/50
# 16/16 [==============================] - 1s 82ms/step - loss: 0.0087 - accuracy: 0.1750
# Epoch 22/50
# 16/16 [==============================] - 2s 101ms/step - loss: 0.0098 - accuracy: 0.1625
# Epoch 23/50
# 16/16 [==============================] - 1s 72ms/step - loss: 0.0092 - accuracy: 0.1750
# Epoch 24/50
# 16/16 [==============================] - 1s 62ms/step - loss: 0.0087 - accuracy: 0.1750
# Epoch 25/50
# 16/16 [==============================] - 1s 86ms/step - loss: 0.0085 - accuracy: 0.1750
# Epoch 26/50
# 16/16 [==============================] - 2s 103ms/step - loss: 0.0080 - accuracy: 0.1750
# Epoch 27/50
# 16/16 [==============================] - 2s 145ms/step - loss: 0.0088 - accuracy: 0.1750
# Epoch 28/50
# 16/16 [==============================] - 1s 61ms/step - loss: 0.0082 - accuracy: 0.1750
# Epoch 29/50
# 16/16 [==============================] - 1s 65ms/step - loss: 0.0088 - accuracy: 0.1750
# Epoch 30/50
# 16/16 [==============================] - 1s 90ms/step - loss: 0.0091 - accuracy: 0.1750
# Epoch 31/50
# 16/16 [==============================] - 1s 92ms/step - loss: 0.0098 - accuracy: 0.1625
# Epoch 32/50
# 16/16 [==============================] - 1s 91ms/step - loss: 0.0082 - accuracy: 0.1750
# Epoch 33/50
# 16/16 [==============================] - 2s 125ms/step - loss: 0.0084 - accuracy: 0.1750
# Epoch 34/50
# 16/16 [==============================] - 3s 160ms/step - loss: 0.0078 - accuracy: 0.1750
# Epoch 35/50
# 16/16 [==============================] - 3s 160ms/step - loss: 0.0087 - accuracy: 0.1750
# Epoch 36/50
# 16/16 [==============================] - 1s 82ms/step - loss: 0.0084 - accuracy: 0.1750
# Epoch 37/50
# 16/16 [==============================] - 1s 55ms/step - loss: 0.0074 - accuracy: 0.1750
# Epoch 38/50
# 16/16 [==============================] - 1s 72ms/step - loss: 0.0089 - accuracy: 0.1750
# Epoch 39/50
# 16/16 [==============================] - 1s 75ms/step - loss: 0.0130 - accuracy: 0.1625
# Epoch 40/50
# 16/16 [==============================] - 1s 75ms/step - loss: 0.0111 - accuracy: 0.1625
# Epoch 41/50
# 16/16 [==============================] - 1s 92ms/step - loss: 0.0087 - accuracy: 0.1750
# Epoch 42/50
# 16/16 [==============================] - 2s 109ms/step - loss: 0.0075 - accuracy: 0.1750
# Epoch 43/50
# 16/16 [==============================] - 1s 75ms/step - loss: 0.0072 - accuracy: 0.1750
# Epoch 44/50
# 16/16 [==============================] - 1s 87ms/step - loss: 0.0090 - accuracy: 0.1625
# Epoch 45/50
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0075 - accuracy: 0.1750
# Epoch 46/50
# 16/16 [==============================] - 1s 68ms/step - loss: 0.0082 - accuracy: 0.1750
# Epoch 47/50
# 16/16 [==============================] - 1s 74ms/step - loss: 0.0071 - accuracy: 0.1750
# Epoch 48/50
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0080 - accuracy: 0.1750
# Epoch 49/50
# 16/16 [==============================] - 1s 77ms/step - loss: 0.0090 - accuracy: 0.1750
# Epoch 50/50
# 16/16 [==============================] - 1s 74ms/step - loss: 0.0102 - accuracy: 0.1750

# %%
pred_list = []
batch = train[-n_input:].reshape((1,n_input,n_features))
for i in range(n_input):
    pred_list.append(model.predict(batch)[0])
    batch = np.append(batch[:,1:,:],[[pred_list[i]]],axis=1)

# %%
df_predict = pd.DataFrame(scaler.inverse_transform(pred_list),index=df[-n_input:].index,columns=['Predictions'])
df_test = pd.concat([df,df_predict],axis=1)

# %%
df_test.tail(15)
# Out:
#             Confirmé    Predictions
# Date
# 2020-06-20        60     160.835080
# 2020-06-21        93     190.807311
# 2020-06-22        44     224.263770
# 2020-06-23        84     287.829523
# 2020-06-24        63     376.251011
# 2020-06-25        42     545.208138
# 2020-06-26        93     911.942448
# 2020-06-27        83    1696.331875
# 2020-06-28        73    3810.686462
# 2020-06-29        60    9128.126678
# 2020-06-30        76   21848.159729
# 2020-07-01        89   52032.427734
# 2020-07-02       100  123938.068359
# 2020-07-03       109  295739.252930
# 2020-07-04       216  706831.628906

# %%
plt.figure(figsize=(15,5))
plt.plot(df_test.index,df_test['Confirmé'])
plt.plot(df_test.index,df_test['Predictions'])

# %%
train = df
scaler = MinMaxScaler()
scaler.fit(train)

train = scaler.transform(train)

n_input = 15
n_features = 1

generator = TimeseriesGenerator(train,train,length=n_input,batch_size=5)
model.fit_generator(generator,epochs=50)

pred_list = []
batch = train[-n_input:].reshape((1,n_input,n_features))
for i in range(n_input):
    pred_list.append(model.predict(batch)[0])
    batch = np.append(batch[:,1:,:],[[pred_list[i]]],axis=1)
# Out:
# Epoch 1/50
# 19/19 [==============================] - 1s 69ms/step - loss: 0.0131 - accuracy: 0.1848
# Epoch 2/50
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0121 - accuracy: 0.1848
# Epoch 3/50
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0076 - accuracy: 0.1957
# Epoch 4/50
# 19/19 [==============================] - 1s 71ms/step - loss: 0.0085 - accuracy: 0.1957
# Epoch 5/50
# 19/19 [==============================] - 2s 82ms/step - loss: 0.0085 - accuracy: 0.1848
# Epoch 6/50
# 19/19 [==============================] - 2s 129ms/step - loss: 0.0105 - accuracy: 0.1957
# Epoch 7/50
# 19/19 [==============================] - 2s 122ms/step - loss: 0.0102 - accuracy: 0.1957
# Epoch 8/50
# 19/19 [==============================] - 2s 94ms/step - loss: 0.0075 - accuracy: 0.1957
# Epoch 9/50
# 19/19 [==============================] - 2s 82ms/step - loss: 0.0077 - accuracy: 0.1957
# Epoch 10/50
# 19/19 [==============================] - 2s 85ms/step - loss: 0.0101 - accuracy: 0.1848
# Epoch 11/50
# 19/19 [==============================] - 1s 69ms/step - loss: 0.0077 - accuracy: 0.1957
# Epoch 12/50
# 19/19 [==============================] - 2s 80ms/step - loss: 0.0080 - accuracy: 0.1957
# Epoch 13/50
# 19/19 [==============================] - 1s 69ms/step - loss: 0.0078 - accuracy: 0.1957
# Epoch 14/50
# 19/19 [==============================] - 1s 78ms/step - loss: 0.0074 - accuracy: 0.1957
# Epoch 15/50
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0075 - accuracy: 0.1957
# Epoch 16/50
# 19/19 [==============================] - 1s 74ms/step - loss: 0.0088 - accuracy: 0.1957
# Epoch 17/50
# 19/19 [==============================] - 2s 82ms/step - loss: 0.0084 - accuracy: 0.1957
# Epoch 18/50
# 19/19 [==============================] - 2s 82ms/step - loss: 0.0075 - accuracy: 0.1957
# Epoch 19/50
# 19/19 [==============================] - 2s 94ms/step - loss: 0.0067 - accuracy: 0.1957
# Epoch 20/50
# 19/19 [==============================] - 2s 96ms/step - loss: 0.0073 - accuracy: 0.1957
# Epoch 21/50
# 19/19 [==============================] - 2s 121ms/step - loss: 0.0071 - accuracy: 0.1957
# Epoch 22/50
# 19/19 [==============================] - 2s 116ms/step - loss: 0.0069 - accuracy: 0.1957
# Epoch 23/50
# 19/19 [==============================] - 2s 121ms/step - loss: 0.0083 - accuracy: 0.1957
# Epoch 24/50
# 19/19 [==============================] - 2s 129ms/step - loss: 0.0068 - accuracy: 0.1957
# Epoch 25/50
# 19/19 [==============================] - 2s 104ms/step - loss: 0.0075 - accuracy: 0.1957
# Epoch 26/50
# 19/19 [==============================] - 2s 89ms/step - loss: 0.0067 - accuracy: 0.1957
# Epoch 27/50
# 19/19 [==============================] - 2s 113ms/step - loss: 0.0081 - accuracy: 0.1957
# Epoch 28/50
# 19/19 [==============================] - 2s 96ms/step - loss: 0.0084 - accuracy: 0.1848
# Epoch 29/50
# 19/19 [==============================] - 3s 135ms/step - loss: 0.0071 - accuracy: 0.1957
# Epoch 30/50
# 19/19 [==============================] - 2s 123ms/step - loss: 0.0078 - accuracy: 0.1957
# Epoch 31/50
# 19/19 [==============================] - 2s 111ms/step - loss: 0.0061 - accuracy: 0.1957
# Epoch 32/50
# 19/19 [==============================] - 4s 229ms/step - loss: 0.0074 - accuracy: 0.1957
# Epoch 33/50
# 19/19 [==============================] - 3s 134ms/step - loss: 0.0083 - accuracy: 0.1957
# Epoch 34/50
# 19/19 [==============================] - 3s 134ms/step - loss: 0.0067 - accuracy: 0.1957
# Epoch 35/50
# 19/19 [==============================] - 3s 135ms/step - loss: 0.0064 - accuracy: 0.1957
# Epoch 36/50
# 19/19 [==============================] - 3s 144ms/step - loss: 0.0074 - accuracy: 0.1957
# Epoch 37/50
# 19/19 [==============================] - 3s 150ms/step - loss: 0.0083 - accuracy: 0.1848
# Epoch 38/50
# 19/19 [==============================] - 3s 136ms/step - loss: 0.0095 - accuracy: 0.1957
# Epoch 39/50
# 19/19 [==============================] - 2s 130ms/step - loss: 0.0073 - accuracy: 0.1957
# Epoch 40/50
# 19/19 [==============================] - 3s 140ms/step - loss: 0.0075 - accuracy: 0.1957
# Epoch 41/50
# 19/19 [==============================] - 2s 127ms/step - loss: 0.0062 - accuracy: 0.1957
# Epoch 42/50
# 19/19 [==============================] - 2s 131ms/step - loss: 0.0074 - accuracy: 0.1957
# Epoch 43/50
# 19/19 [==============================] - 3s 163ms/step - loss: 0.0074 - accuracy: 0.1957
# Epoch 44/50
# 19/19 [==============================] - 4s 191ms/step - loss: 0.0066 - accuracy: 0.1957
# Epoch 45/50
# 19/19 [==============================] - 3s 165ms/step - loss: 0.0087 - accuracy: 0.1957
# Epoch 46/50
# 19/19 [==============================] - 3s 165ms/step - loss: 0.0084 - accuracy: 0.1848
# Epoch 47/50
# 19/19 [==============================] - 3s 171ms/step - loss: 0.0060 - accuracy: 0.1957
# Epoch 48/50
# 19/19 [==============================] - 3s 148ms/step - loss: 0.0079 - accuracy: 0.1957
# Epoch 49/50
# 19/19 [==============================] - 3s 147ms/step - loss: 0.0063 - accuracy: 0.1957
# Epoch 50/50
# 19/19 [==============================] - 2s 99ms/step - loss: 0.0084 - accuracy: 0.1957

# %%
add_dates = [df.index[-1] + DateOffset(day=x)for x in range(4,20)]
future_dates = pd.DataFrame(index=add_dates[1:],columns=df.columns)
future_dates.tail(30)
# Out:
#            Confirmé
# 2020-07-05      NaN
# 2020-07-06      NaN
# 2020-07-07      NaN
# 2020-07-08      NaN
# 2020-07-09      NaN
# 2020-07-10      NaN
# 2020-07-11      NaN
# 2020-07-12      NaN
# 2020-07-13      NaN
# 2020-07-14      NaN
# 2020-07-15      NaN
# 2020-07-16      NaN
# 2020-07-17      NaN
# 2020-07-18      NaN
# 2020-07-19      NaN

# %%
df_predict = pd.DataFrame(scaler.inverse_transform(pred_list),index=future_dates[-n_input:].index,columns=['Predictions'])

df_future = pd.concat([df,df_predict],axis=1)
df_future.tail(20)
# Out:
#             Confirmé   Predictions
# 2020-06-30      76.0           NaN
# 2020-07-01      89.0           NaN
# 2020-07-02     100.0           NaN
# 2020-07-03     109.0           NaN
# 2020-07-04     216.0           NaN
# 2020-07-05       NaN  1.921764e+02
# 2020-07-06       NaN  2.458643e+02
# 2020-07-07       NaN  3.227786e+02
# 2020-07-08       NaN  4.883761e+02
# 2020-07-09       NaN  8.233107e+02
# 2020-07-10       NaN  1.734240e+03
# 2020-07-11       NaN  4.352651e+03
# 2020-07-12       NaN  1.072295e+04
# 2020-07-13       NaN  2.680224e+04
# 2020-07-14       NaN  6.776900e+04
# 2020-07-15       NaN  1.723916e+05
# 2020-07-16       NaN  4.389023e+05
# 2020-07-17       NaN  1.118978e+06
# 2020-07-18       NaN  2.854814e+06
# 2020-07-19       NaN  7.285285e+06

# %%
plt.figure(figsize=(15,5))
plt.bar(df_future.index,df_future['Confirmé'])
#plt.plot(df_future.index,df_future['Predictions'])
# Out:
# <BarContainer object of 122 artists>
